# %% [markdown]
# # This is Mybinder example
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/ketilroed/mybinder-example/HEAD)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0,10,1)
y = 2 * x**2

# %%
plt.plot(x,y)
